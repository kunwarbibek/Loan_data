# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
dataset.isnull().sum()
# Out:
# Age           0
# Experience    0
# Salary        0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Age         400 non-null    int64
#  1   Experience  400 non-null    int64
#  2   Salary      400 non-null    float64
# dtypes: float64(1), int64(2)
# memory usage: 9.5 KB

# %%
sns.pairplot(data=dataset)
plt.show()

# %%
sns.heatmap(data=dataset.corr(), annot=True)
plt.show()

# %%
x= dataset.iloc[:,:-1]
x.ndim
y=dataset[["Salary"]]
y.ndim
# Out:
# 2

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
lr= LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.9592200594880378

# %%
# Y=M1*x1+m2x2+..............+c
lr.coef_
# Out:
# array([[ 490.03315433, 1008.17723955]])

# %%
lr.intercept_
# Out:
# array([30440.48214388])

# %%
lr.predict(x_test)
# Out:
# array([[74406.72765161],
#        [85761.82299383],
#        [70920.27370952],
#        [55628.94953085],
#        [80230.90364174],
#        [64967.69039396],
#        [56552.79397771],
#        [70639.16440054],
#        [85131.23518501],
#        [54243.18286056],
#        [90634.0436062 ],
#        [50238.58483325],
#        [70470.49881515],
#        [73145.55203397],
#        [68566.58805964],
#        [75904.93804549],
#        [68972.28842127],
#        [58709.7031113 ],
#        [76744.44969965],
#        [64100.0678089 ],
#        [48684.15257757],
#        [83661.13572203],
#        [53696.92784444],
#        [59830.32407445],
#        [55950.31709979],
#        [71928.45094907],
#        [54158.85006787],
#        [66984.04487307],
#        [55978.42803068],
#        [60348.46815967],
#        [77459.37030116],
#        [55488.39487636],
#        [78158.32730084],
#        [65738.83285727],
#        [91152.18769142],
#        [58428.59380232],
#        [80692.82586517],
#        [77346.92657757],
#        [61159.86888294],
#        [78355.10381712],
#        [62405.08089873],
#        [66803.23195862],
#        [71466.52872565],
#        [76800.67156145],
#        [75021.35185859],
#        [79082.17174769],
#        [84123.05794546],
#        [63610.03465457],
#        [69112.84307576],
#        [59830.32407445],
#        [69462.3215756 ],
#        [57476.63842456],
#        [59436.77104187],
#        [59171.62533473],
#        [68538.47712874],
#        [84809.86761607],
#        [63638.14558547],
#        [56412.23932322],
#        [57070.93806293],
#        [83633.02479113],
#        [62224.26798429],
#        [73663.6961192 ],
#        [81757.22496651],
#        [86770.00023338],
#        [60906.87050485],
#        [48166.00849235],
#        [72362.26224161],
#        [75049.46278948],
#        [64409.28804878],
#        [66341.30973519],
#        [72277.92944891],
#        [63035.66870755],
#        [75190.01744398],
#        [80315.23643443],
#        [58372.37194052],
#        [70779.71905503],
#        [79391.39198757],
#        [83773.57944562],
#        [79515.98304022],
#        [67405.70883654]])

# %%
age = float(input("Enter Age: "))
experience = float(input("Enter Experience: "))
new_data = pd.DataFrame([[age, experience]], columns=["Age", "Experience"])
predicted_salary = lr.predict(new_data)
salary = predicted_salary.item()  

print(f"Predicted Salary: {salary:.2f}")
# Out:
# Enter Age:  36
# Enter Experience:  27
# Predicted Salary: 75302.46
